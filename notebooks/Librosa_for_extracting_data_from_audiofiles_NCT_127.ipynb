# %% [markdown]
# <a href="https://colab.research.google.com/github/masevs/nct27-complexity-analysis/blob/main/notebooks/Librosa_for_extracting_data_from_audiofiles_NCT_127.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install librosa pandas numpy matplotlib

# %%
# NCT 127 Audio Feature Extractor - Colab Version
# Upload individual audio files, extract features one-by-one, and combine

import librosa
import numpy as np
import pandas as pd
import os
from google.colab import files

# === STEP 1: Upload one or more audio files manually ===
print("📂 Please upload your .mp3 or .wav files")
uploaded = files.upload()

# === STEP 2: Feature extraction function ===
def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
        flatness = librosa.feature.spectral_flatness(y=y)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        mfccs = librosa.feature.mfcc(y=y, sr=sr)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        pitches, mags = librosa.piptrack(y=y, sr=sr)

        pitch_values = pitches[mags > np.median(mags)]
        pitch_range = np.max(pitch_values) - np.min(pitch_values) if len(pitch_values) > 0 else 0

        return {
            'tempo': tempo,
            'mfcc_var': np.var(mfccs),
            'spectral_centroid_mean': np.mean(centroid),
            'spectral_flatness_mean': np.mean(flatness),
            'spectral_contrast_mean': np.mean(contrast),
            'onset_strength_mean': np.mean(onset_env),
            'pitch_range': pitch_range
        }
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# === STEP 3: Process each uploaded file ===
all_features = []

for file_name in uploaded.keys():
    print(f"\n🔍 Extracting from: {file_name}")
    features = extract_features(file_name)
    if features:
        features['track'] = file_name
        all_features.append(features)
        # Save individual feature file
        pd.DataFrame([features]).to_csv(f"{file_name}_features.csv", index=False)
        print(f"✅ Features saved: {file_name}_features.csv")
    else:
        print(f"⚠️ Skipped: {file_name}")

# === STEP 4: Combine all features into one CSV ===
if all_features:
    combined_df = pd.DataFrame(all_features)
    combined_df.to_csv("nct127_combined_features.csv", index=False)
    print("\n✅ All features combined and saved as 'nct127_combined_features.csv'")
else:
    print("❌ No features extracted.")
# Out:
# 📂 Please upload your .mp3 or .wav files
#      <input type="file" id="files-9b86ea61-3a01-4669-bc40-0f2206bf2fc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b86ea61-3a01-4669-bc40-0f2206bf2fc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# NCT 127 Audio Feature Extractor - Colab Version
# Upload individual audio files, extract features one-by-one, and combine

import librosa
import numpy as np
import pandas as pd
import os
from google.colab import files

# === STEP 1: Upload one or more audio files manually ===
print("📂 Please upload your .mp3 or .wav files")
uploaded = files.upload()

# === STEP 2: Feature extraction function ===
def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
        flatness = librosa.feature.spectral_flatness(y=y)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        mfccs = librosa.feature.mfcc(y=y, sr=sr)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        pitches, mags = librosa.piptrack(y=y, sr=sr)

        pitch_values = pitches[mags > np.median(mags)]
        pitch_range = np.max(pitch_values) - np.min(pitch_values) if len(pitch_values) > 0 else 0

        return {
            'tempo': tempo,
            'mfcc_var': np.var(mfccs),
            'spectral_centroid_mean': np.mean(centroid),
            'spectral_flatness_mean': np.mean(flatness),
            'spectral_contrast_mean': np.mean(contrast),
            'onset_strength_mean': np.mean(onset_env),
            'pitch_range': pitch_range
        }
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# === STEP 3: Process each uploaded file ===
all_features = []

for file_name in uploaded.keys():
    print(f"\n🔍 Extracting from: {file_name}")
    features = extract_features(file_name)
    if features:
        features['track'] = file_name
        all_features.append(features)
        # Save individual feature file
        pd.DataFrame([features]).to_csv(f"{file_name}_features.csv", index=False)
        print(f"✅ Features saved: {file_name}_features.csv")
    else:
        print(f"⚠️ Skipped: {file_name}")

# === STEP 4: Combine all features into one CSV ===
if all_features:
    combined_df = pd.DataFrame(all_features)
    combined_df.to_csv("nct127_combined_features.csv", index=False)
    print("\n✅ All features combined and saved as 'nct127_combined_features.csv'")
else:
    print("❌ No features extracted.")
# Out:
# 📂 Please upload your .mp3 or .wav files
#      <input type="file" id="files-a255754f-d8a2-4a41-bd74-bf09606cccbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a255754f-d8a2-4a41-bd74-bf09606cccbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# NCT 127 Audio Feature Extractor - Colab Version
# Upload individual audio files, extract features one-by-one, and combine

import librosa
import numpy as np
import pandas as pd
import os
from google.colab import files

# === STEP 1: Upload one or more audio files manually ===
print("📂 Please upload your .mp3 or .wav files")
uploaded = files.upload()

# === STEP 2: Feature extraction function ===
def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
        flatness = librosa.feature.spectral_flatness(y=y)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        mfccs = librosa.feature.mfcc(y=y, sr=sr)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        pitches, mags = librosa.piptrack(y=y, sr=sr)

        pitch_values = pitches[mags > np.median(mags)]
        pitch_range = np.max(pitch_values) - np.min(pitch_values) if len(pitch_values) > 0 else 0

        return {
            'tempo': tempo,
            'mfcc_var': np.var(mfccs),
            'spectral_centroid_mean': np.mean(centroid),
            'spectral_flatness_mean': np.mean(flatness),
            'spectral_contrast_mean': np.mean(contrast),
            'onset_strength_mean': np.mean(onset_env),
            'pitch_range': pitch_range
        }
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# === STEP 3: Process each uploaded file ===
all_features = []

for file_name in uploaded.keys():
    print(f"\n🔍 Extracting from: {file_name}")
    features = extract_features(file_name)
    if features:
        features['track'] = file_name
        all_features.append(features)
        # Save individual feature file
        pd.DataFrame([features]).to_csv(f"{file_name}_features.csv", index=False)
        print(f"✅ Features saved: {file_name}_features.csv")
    else:
        print(f"⚠️ Skipped: {file_name}")

# === STEP 4: Combine all features into one CSV ===
if all_features:
    combined_df = pd.DataFrame(all_features)
    combined_df.to_csv("nct127_combined_features.csv", index=False)
    print("\n✅ All features combined and saved as 'nct127_combined_features.csv'")
else:
    print("❌ No features extracted.")
# Out:
# 📂 Please upload your .mp3 or .wav files
#      <input type="file" id="files-d6b4c9f1-8bc7-45fc-9efd-1f850e8e5c92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6b4c9f1-8bc7-45fc-9efd-1f850e8e5c92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# NCT 127 Audio Feature Extractor - Colab Version
# Upload individual audio files, extract features one-by-one, and combine

import librosa
import numpy as np
import pandas as pd
import os
from google.colab import files

# === STEP 1: Upload one or more audio files manually ===
print("📂 Please upload your .mp3 or .wav files")
uploaded = files.upload()

# === STEP 2: Feature extraction function ===
def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
        flatness = librosa.feature.spectral_flatness(y=y)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        mfccs = librosa.feature.mfcc(y=y, sr=sr)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        pitches, mags = librosa.piptrack(y=y, sr=sr)

        pitch_values = pitches[mags > np.median(mags)]
        pitch_range = np.max(pitch_values) - np.min(pitch_values) if len(pitch_values) > 0 else 0

        return {
            'tempo': tempo,
            'mfcc_var': np.var(mfccs),
            'spectral_centroid_mean': np.mean(centroid),
            'spectral_flatness_mean': np.mean(flatness),
            'spectral_contrast_mean': np.mean(contrast),
            'onset_strength_mean': np.mean(onset_env),
            'pitch_range': pitch_range
        }
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# === STEP 3: Process each uploaded file ===
all_features = []

for file_name in uploaded.keys():
    print(f"\n🔍 Extracting from: {file_name}")
    features = extract_features(file_name)
    if features:
        features['track'] = file_name
        all_features.append(features)
        # Save individual feature file
        pd.DataFrame([features]).to_csv(f"{file_name}_features.csv", index=False)
        print(f"✅ Features saved: {file_name}_features.csv")
    else:
        print(f"⚠️ Skipped: {file_name}")

# === STEP 4: Combine all features into one CSV ===
if all_features:
    combined_df = pd.DataFrame(all_features)
    combined_df.to_csv("nct127_combined_features.csv", index=False)
    print("\n✅ All features combined and saved as 'nct127_combined_features.csv'")
else:
    print("❌ No features extracted.")
# Out:
# 📂 Please upload your .mp3 or .wav files
#      <input type="file" id="files-6badaba4-3478-4883-9b77-399e205f4233" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6badaba4-3478-4883-9b77-399e205f4233">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# NCT 127 Audio Feature Extractor - Colab Version
# Upload individual audio files, extract features one-by-one, and combine

import librosa
import numpy as np
import pandas as pd
import os
from google.colab import files

# === STEP 1: Upload one or more audio files manually ===
print("📂 Please upload your .mp3 or .wav files")
uploaded = files.upload()

# === STEP 2: Feature extraction function ===
def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
        flatness = librosa.feature.spectral_flatness(y=y)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        mfccs = librosa.feature.mfcc(y=y, sr=sr)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        pitches, mags = librosa.piptrack(y=y, sr=sr)

        pitch_values = pitches[mags > np.median(mags)]
        pitch_range = np.max(pitch_values) - np.min(pitch_values) if len(pitch_values) > 0 else 0

        return {
            'tempo': tempo,
            'mfcc_var': np.var(mfccs),
            'spectral_centroid_mean': np.mean(centroid),
            'spectral_flatness_mean': np.mean(flatness),
            'spectral_contrast_mean': np.mean(contrast),
            'onset_strength_mean': np.mean(onset_env),
            'pitch_range': pitch_range
        }
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# === STEP 3: Process each uploaded file ===
all_features = []

for file_name in uploaded.keys():
    print(f"\n🔍 Extracting from: {file_name}")
    features = extract_features(file_name)
    if features:
        features['track'] = file_name
        all_features.append(features)
        # Save individual feature file
        pd.DataFrame([features]).to_csv(f"{file_name}_features.csv", index=False)
        print(f"✅ Features saved: {file_name}_features.csv")
    else:
        print(f"⚠️ Skipped: {file_name}")

# === STEP 4: Combine all features into one CSV ===
if all_features:
    combined_df = pd.DataFrame(all_features)
    combined_df.to_csv("nct127_combined_features.csv", index=False)
    print("\n✅ All features combined and saved as 'nct127_combined_features.csv'")
else:
    print("❌ No features extracted.")
# Out:
# 📂 Please upload your .mp3 or .wav files
#      <input type="file" id="files-6f1c5af8-ef94-4073-bf09-dbf3fad6421f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f1c5af8-ef94-4073-bf09-dbf3fad6421f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# NCT 127 Audio Feature Extractor - Colab Version
# Upload individual audio files, extract features one-by-one, and combine

import librosa
import numpy as np
import pandas as pd
import os
from google.colab import files

# === STEP 1: Upload one or more audio files manually ===
print("📂 Please upload your .mp3 or .wav files")
uploaded = files.upload()

# === STEP 2: Feature extraction function ===
def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
        flatness = librosa.feature.spectral_flatness(y=y)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        mfccs = librosa.feature.mfcc(y=y, sr=sr)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        pitches, mags = librosa.piptrack(y=y, sr=sr)

        pitch_values = pitches[mags > np.median(mags)]
        pitch_range = np.max(pitch_values) - np.min(pitch_values) if len(pitch_values) > 0 else 0

        return {
            'tempo': tempo,
            'mfcc_var': np.var(mfccs),
            'spectral_centroid_mean': np.mean(centroid),
            'spectral_flatness_mean': np.mean(flatness),
            'spectral_contrast_mean': np.mean(contrast),
            'onset_strength_mean': np.mean(onset_env),
            'pitch_range': pitch_range
        }
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# === STEP 3: Process each uploaded file ===
all_features = []

for file_name in uploaded.keys():
    print(f"\n🔍 Extracting from: {file_name}")
    features = extract_features(file_name)
    if features:
        features['track'] = file_name
        all_features.append(features)
        # Save individual feature file
        pd.DataFrame([features]).to_csv(f"{file_name}_features.csv", index=False)
        print(f"✅ Features saved: {file_name}_features.csv")
    else:
        print(f"⚠️ Skipped: {file_name}")

# === STEP 4: Combine all features into one CSV ===
if all_features:
    combined_df = pd.DataFrame(all_features)
    combined_df.to_csv("nct127_combined_features.csv", index=False)
    print("\n✅ All features combined and saved as 'nct127_combined_features.csv'")
else:
    print("❌ No features extracted.")
# Out:
# 📂 Please upload your .mp3 or .wav files
#      <input type="file" id="files-e91bbc68-0294-40a9-9bda-f69289e609b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e91bbc68-0294-40a9-9bda-f69289e609b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# NCT 127 Audio Feature Extractor - Colab Version
# Upload individual audio files, extract features one-by-one, and combine

import librosa
import numpy as np
import pandas as pd
import os
from google.colab import files

# === STEP 1: Upload one or more audio files manually ===
print("📂 Please upload your .mp3 or .wav files")
uploaded = files.upload()

# === STEP 2: Feature extraction function ===
def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path, sr=22050)

        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
        flatness = librosa.feature.spectral_flatness(y=y)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        mfccs = librosa.feature.mfcc(y=y, sr=sr)
        onset_env = librosa.onset.onset_strength(y=y, sr=sr)
        pitches, mags = librosa.piptrack(y=y, sr=sr)

        pitch_values = pitches[mags > np.median(mags)]
        pitch_range = np.max(pitch_values) - np.min(pitch_values) if len(pitch_values) > 0 else 0

        return {
            'tempo': tempo,
            'mfcc_var': np.var(mfccs),
            'spectral_centroid_mean': np.mean(centroid),
            'spectral_flatness_mean': np.mean(flatness),
            'spectral_contrast_mean': np.mean(contrast),
            'onset_strength_mean': np.mean(onset_env),
            'pitch_range': pitch_range
        }
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

# === STEP 3: Process each uploaded file ===
all_features = []

for file_name in uploaded.keys():
    print(f"\n🔍 Extracting from: {file_name}")
    features = extract_features(file_name)
    if features:
        features['track'] = file_name
        all_features.append(features)
        # Save individual feature file
        pd.DataFrame([features]).to_csv(f"{file_name}_features.csv", index=False)
        print(f"✅ Features saved: {file_name}_features.csv")
    else:
        print(f"⚠️ Skipped: {file_name}")

# === STEP 4: Combine all features into one CSV ===
if all_features:
    combined_df = pd.DataFrame(all_features)
    combined_df.to_csv("nct127_combined_features.csv", index=False)
    print("\n✅ All features combined and saved as 'nct127_combined_features.csv'")
else:
    print("❌ No features extracted.")
# Out:
# 📂 Please upload your .mp3 or .wav files
#      <input type="file" id="files-379c5368-d805-4ea3-8472-2767708047f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-379c5368-d805-4ea3-8472-2767708047f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
import pandas as pd
import glob

# Find all CSVs with *_features.csv
# Use a single pattern to match all relevant files.
csv_files = glob.glob("/content/*_features.csv")

# Combine into one DataFrame
combined_df = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

# Save the final combined CSV
combined_df.to_csv("nct127_all_features_combined.csv", index=False)

# Show preview
combined_df.head()
# Out:
#             tempo    mfcc_var  spectral_centroid_mean  spectral_flatness_mean  \
# 0  [161.49902344]   716.99350             2655.461646                0.035007
# 1    [86.1328125]   792.49490             2625.322497                0.034905
# 2   [89.10290948]   998.89026             2489.159389                0.027172
# 3   [78.30255682]   997.36536             2425.999257                0.021735
# 4  [151.99908088]  2130.45780             2378.761073                0.063908
#
#    spectral_contrast_mean  onset_strength_mean  pitch_range  \
# 0               21.896637             1.632117    3854.4233
# 1               20.793282             1.540898    3854.0645
# 2               21.705157             1.593173    3854.3997
# 3               21.715575             1.621376    3854.0103
# 4               21.688688             1.417547    3854.2632
#
#                  track
# 0      Kick It (1).wav
# 1    2 Baddies (1).wav
# 2        Ay yo (1).wav
# 3  Cherry Bomb (1).wav
# ...

# %%
# @title tempo vs mfcc_var

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(combined_df['tempo'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(combined_df, x='mfcc_var', y='tempo', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-58-8f1478815e32>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(combined_df, x='mfcc_var', y='tempo', inner='stick', palette='Dark2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

for col in df.columns:
    if col != "track":
        plt.figure(figsize=(6, 4))
        sns.histplot(df[col], kde=True)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.tight_layout()
        plt.show()

# %%
import pandas as pd

df = pd.read_csv("nct127_all_features_combined.csv")
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tempo                   7 non-null      object
#  1   mfcc_var                7 non-null      float64
#  2   spectral_centroid_mean  7 non-null      float64
#  3   spectral_flatness_mean  7 non-null      float64
#  4   spectral_contrast_mean  7 non-null      float64
#  5   onset_strength_mean     7 non-null      float64
#  6   pitch_range             7 non-null      float64
#  7   track                   7 non-null      object
# dtypes: float64(6), object(2)
# memory usage: 580.0+ bytes
# None
#             tempo    mfcc_var  spectral_centroid_mean  spectral_flatness_mean  \
# 0  [161.49902344]   716.99350             2655.461646                0.035007
# 1    [86.1328125]   792.49490             2625.322497                0.034905
# ...

# %%
print(df.describe())
print(df['track'].value_counts())  # Make sure all track names are unique
# Out:
#           mfcc_var  spectral_centroid_mean  spectral_flatness_mean  \
# count     7.000000                7.000000                7.000000
# mean   1072.085540             2534.013892                0.035469
# std     480.527693              118.557054                0.014186
# min     716.993500             2378.761073                0.021735
# 25%     824.517380             2455.219268                0.026002
# 50%     997.365360             2489.159389                0.034905
# 75%    1005.373680             2640.392071                0.037865
# max    2130.457800             2678.954102                0.063908
#
#        spectral_contrast_mean  onset_strength_mean  pitch_range
# count                7.000000             7.000000     7.000000
# mean                21.744754             1.593122  3854.271100
# std                  0.746329             0.128162     0.170614
# min                 20.793282             1.417547  3854.010300
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

for col in df.columns:
    if col != "track":
        plt.figure(figsize=(6, 4))
        sns.histplot(df[col], kde=True)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.drop(columns='track').corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Between Features")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-7316129daa00> in <cell line: 0>()
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.heatmap(df.drop(columns='track').corr(), annot=True, cmap='coolwarm', fmt=".2f")
#       3 plt.title("Correlation Between Features")
#       4 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# ... (your previous code) ...

# Convert 'tempo' column to numeric, handling potential errors
df['tempo'] = pd.to_numeric(df['tempo'].str.strip('[]'), errors='coerce')

plt.figure(figsize=(10, 6))
sns.heatmap(df.drop(columns='track').corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Between Features")
plt.show()

# %%
from math import pi

# Normalize features for radar plot
features = df.drop(columns='track').copy()
features_normalized = (features - features.min()) / (features.max() - features.min())
features_normalized['track'] = df['track']

# Radar chart for one song
track = "Sticker (1).wav"  # Replace with any track name you want
row = features_normalized[features_normalized['track'] == track].drop(columns='track').iloc[0]

labels = row.index
values = row.values.tolist()
values += values[:1]  # close the circle

angles = [n / float(len(labels)) * 2 * pi for n in range(len(labels))]
angles += angles[:1]

plt.figure(figsize=(6, 6))
ax = plt.subplot(111, polar=True)
plt.xticks(angles[:-1], labels, color='grey', size=8)
ax.plot(angles, values, linewidth=2, linestyle='solid')
ax.fill(angles, values, alpha=0.3)
plt.title(f"Audio Feature Profile: {track}")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# Load your extracted feature dataset
df = pd.read_csv("nct127_all_features_combined.csv")

# Convert 'tempo' column to numeric before scaling
df['tempo'] = df['tempo'].str.strip('[]').astype(float) # Convert tempo to numeric

# Normalize numeric features (excluding 'track')
features = df.drop(columns='track')
scaler = MinMaxScaler()
normalized = scaler.fit_transform(features)
df_norm = pd.DataFrame(normalized, columns=features.columns)
df_norm['track'] = df['track']

# Create complexity and hardness scores
df_norm['complexity_score'] = df_norm[['mfcc_var', 'spectral_contrast_mean', 'pitch_range']].mean(axis=1)
df_norm['hardness_score'] = df_norm[['tempo', 'onset_strength_mean', 'spectral_flatness_mean']].mean(axis=1)

# Create summary table
summary_table = df_norm[['track', 'complexity_score', 'hardness_score']].sort_values(by='complexity_score', ascending=False)
summary_table.reset_index(drop=True, inplace=True)
print(summary_table)

# Plot: Complexity vs Hardness
plt.figure(figsize=(10, 6))
sns.scatterplot(data=summary_table, x='complexity_score', y='hardness_score', hue='track', s=100)
plt.title("Complexity vs. Hardness of NCT 127 Songs")
plt.xlabel("Musical Complexity Score")
plt.ylabel("Perceptual Hardness Score")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#                  track  complexity_score  hardness_score
# 0      Sticker (1).wav          0.733298        0.653082
# 1   Simon Says (1).wav          0.661353        0.628604
# 2        Ay yo (1).wav          0.506947        0.227779
# 3      Kick It (1).wav          0.486012        0.611156
# 4   Fact Check (1).wav          0.338357        0.432991
# 5  Cherry Bomb (1).wav          0.193743        0.164263
# 6    2 Baddies (1).wav          0.061550        0.234871
